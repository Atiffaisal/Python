# %% [markdown]
# <a href="https://colab.research.google.com/github/Atiffaisal/Python/blob/main/Pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Pandas has two types of data structure
# 1) **Series** : it's a one dimensional array with indexes. It store single row or column of data in a DataFrame
#
# 2) **DataFrame** : it's a tabular spreadsheet like a structure representing rows each of which one or multiple column

# %%
# !pip install pandas

# %% [markdown]
# ###First we will see **Series**

# %%
import numpy as np
import pandas as pd

# %%
S = pd.Series([1,2,3,4,np.nan,6,7])
S
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    6.0
# 6    7.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.randn(3,4))
df1
# Out:
#           0         1         2         3
# 0  0.651141 -1.741064  0.186883 -0.461171
# 1  1.026477  0.638610 -0.701850 -1.129667
# 2 -1.607727  0.468731  0.051550  0.492160

# %% [markdown]
# ####Changing index **NAME**

# %%
df1.index=['first','second','third']
df1
# Out:
#                0         1         2         3
# first   0.651141 -1.741064  0.186883 -0.461171
# second  1.026477  0.638610 -0.701850 -1.129667
# third  -1.607727  0.468731  0.051550  0.492160

# %%
df=pd.DataFrame(np.random.randn(6,4), columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0 -0.457008  1.261799 -0.034156  0.659781
# 1 -1.430819  0.351437  0.599685  0.523046
# 2  0.781870 -0.072111 -1.427081 -0.261513
# 3 -0.698252 -0.012761  2.005674 -1.116785
# 4 -1.008339 -1.168466  0.769906 -0.226517
# 5 -0.481128 -2.240409  1.693181  0.331325

# %% [markdown]
# ###Creating DataFrame by using dictionary

# %%
Students = {"First_Name":['Atif','Faisal','Khan','Hatim'],
"Class":['MCA','B.tech','BCA','M.tech'],
"Marks": [100,140,120,300 ]}
df = pd.DataFrame(Students)
df
# Out:
#   First_Name   Class  Marks
# 0       Atif     MCA    100
# 1     Faisal  B.tech    140
# 2       Khan     BCA    120
# 3      Hatim  M.tech    300

# %%
Students = {"First_Name":['Atif','Faisal','Khan','Hatim','A','B','C','D','E'],
"Class":['MCA','B.tech','BCA','M.tech','10','11','12','9','8'],
"Marks": [100,140,120,300,23,12,45,67,54]}
df = pd.DataFrame(Students)
df
# Out:
#   First_Name   Class  Marks
# 0       Atif     MCA    100
# 1     Faisal  B.tech    140
# 2       Khan     BCA    120
# 3      Hatim  M.tech    300
# 4          A      10     23
# 5          B      11     12
# 6          C      12     45
# 7          D       9     67
# 8          E       8     54

# %%
df.dtypes
# Out:
# First_Name    object
# Class         object
# Marks          int64
# dtype: object

# %%
df.head(3)
# Out:
#   First_Name   Class  Marks
# 0       Atif     MCA    100
# 1     Faisal  B.tech    140
# 2       Khan     BCA    120

# %%
df.tail()
# Out:
#   First_Name Class  Marks
# 4          A    10     23
# 5          B    11     12
# 6          C    12     45
# 7          D     9     67
# 8          E     8     54

# %%
df.describe()
# Out:
#             Marks
# count    9.000000
# mean    95.666667
# std     87.845034
# min     12.000000
# 25%     45.000000
# 50%     67.000000
# 75%    120.000000
# max    300.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df.columns
# Out:
# Index(['First_Name', 'Class', 'Marks'], dtype='object')

# %%
df.T
# Out:
#                0       1     2       3   4   5   6   7   8
# First_Name  Atif  Faisal  Khan   Hatim   A   B   C   D   E
# Class        MCA  B.tech   BCA  M.tech  10  11  12   9   8
# Marks        100     140   120     300  23  12  45  67  54

# %%
df
# Out:
#   First_Name   Class  Marks
# 0       Atif     MCA    100
# 1     Faisal  B.tech    140
# 2       Khan     BCA    120
# 3      Hatim  M.tech    300
# 4          A      10     23
# 5          B      11     12
# 6          C      12     45
# 7          D       9     67
# 8          E       8     54

# %%
df['First_Name']
# Out:
# 0      Atif
# 1    Faisal
# 2      Khan
# 3     Hatim
# 4         A
# 5         B
# 6         C
# 7         D
# 8         E
# Name: First_Name, dtype: object

# %%
df['Marks']
# Out:
# 0    100
# 1    140
# 2    120
# 3    300
# 4     23
# 5     12
# 6     45
# 7     67
# 8     54
# Name: Marks, dtype: int64

# %%
df[['First_Name','Marks']]
# Out:
#   First_Name  Marks
# 0       Atif    100
# 1     Faisal    140
# 2       Khan    120
# 3      Hatim    300
# 4          A     23
# 5          B     12
# 6          C     45
# 7          D     67
# 8          E     54

# %%
df[2:6]
# Out:
#   First_Name   Class  Marks
# 2       Khan     BCA    120
# 3      Hatim  M.tech    300
# 4          A      10     23
# 5          B      11     12

# %%
df.loc[0,'Class']
# Out:
# 'MCA'

# %%
df.loc[6,'Class']
# Out:
# '12'

# %%
df.loc[3,'First_Name']
# Out:
# 'Hatim'

# %%
df.loc[0,['Class','First_Name']]
# Out:
# Class          MCA
# First_Name    Atif
# Name: 0, dtype: object

# %%
df.loc[[0,4],['Class','First_Name']]
# Out:
#   Class First_Name
# 0   MCA       Atif
# 4    10          A

# %%
df.loc[0:4,['Class','First_Name']]
# Out:
#     Class First_Name
# 0     MCA       Atif
# 1  B.tech     Faisal
# 2     BCA       Khan
# 3  M.tech      Hatim
# 4      10          A

# %%
df[df['Marks']>50]
# Out:
#   First_Name   Class  Marks
# 0       Atif     MCA    100
# 1     Faisal  B.tech    140
# 2       Khan     BCA    120
# 3      Hatim  M.tech    300
# 7          D       9     67
# 8          E       8     54

# %%
df.set_index('First_Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-780f2df2a352> in <module>()
# ----> 1 df.set_index('First_Name')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['First_Name'] are in the columns"

# %%
df.set_index('First_Name', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-cb5ef363cb2b> in <module>()
# ----> 1 df.set_index('First_Name', inplace = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['First_Name'] are in the columns"

# %%
df
# Out:
#              Class  Marks
# First_Name
# Atif           MCA    100
# Faisal      B.tech    140
# Khan           BCA    120
# Hatim       M.tech    300
# A               10     23
# B               11     12
# C               12     45
# D                9     67
# E                8     54

# %%
df.loc['Atif']
# Out:
# Class    MCA
# Marks    100
# Name: Atif, dtype: object

# %%
df.loc['Khan']
# Out:
# Class    BCA
# Marks    120
# Name: Khan, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   First_Name   Class  Marks
# 0       Atif     MCA    100
# 1     Faisal  B.tech    140
# 2       Khan     BCA    120
# 3      Hatim  M.tech    300
# 4          A      10     23
# 5          B      11     12
# 6          C      12     45
# 7          D       9     67
# 8          E       8     54

# %%
df.sort_index(ascending=False)
# Out:
#   First_Name   Class  Marks
# 8          E       8     54
# 7          D       9     67
# 6          C      12     45
# 5          B      11     12
# 4          A      10     23
# 3      Hatim  M.tech    300
# 2       Khan     BCA    120
# 1     Faisal  B.tech    140
# 0       Atif     MCA    100

# %% [markdown]
# ###We are using here **filter** and **&** function for finding any specific name

# %%
filter = (df['First_Name']=='Hatim') & (df['Class']=='M.tech')
filter
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
countries = ['India','Pakistan','China','Japan','Russia','Kuwait','India','India','Saudia Arab']
df['Country']=countries
df
# Out:
#   First_Name   Class  Marks      Country
# 0       Atif     MCA    100        India
# 1     Faisal  B.tech    140     Pakistan
# 2       Khan     BCA    120        China
# 3      Hatim  M.tech    300        Japan
# 4          A      10     23       Russia
# 5          B      11     12       Kuwait
# 6          C      12     45        India
# 7          D       9     67        India
# 8          E       8     54  Saudia Arab

# %%
df.rename(columns={'First_Name':'Name'}, inplace=True)
df
# Out:
#      Name   Class  Marks      Country
# 0    Atif     MCA    100        India
# 1  Faisal  B.tech    140     Pakistan
# 2    Khan     BCA    120        China
# 3   Hatim  M.tech    300        Japan
# 4       A      10     23       Russia
# 5       B      11     12       Kuwait
# 6       C      12     45        India
# 7       D       9     67        India
# 8       E       8     54  Saudia Arab

# %%
df.loc[4]=['Amir','C.Sci.',190,'Dubai']
df
# Out:
#      Name   Class  Marks      Country
# 0    Atif     MCA    100        India
# 1  Faisal  B.tech    140     Pakistan
# 2    Khan     BCA    120        China
# 3   Hatim  M.tech    300        Japan
# 4    Amir  C.Sci.    190        Dubai
# 5       B      11     12       Kuwait
# 6       C      12     45        India
# 7       D       9     67        India
# 8       E       8     54  Saudia Arab

# %% [markdown]
# ###Replacing Same country name

# %%
df['Country']=df['Country']. replace({'India':'German'})
df
# Out:
#      Name   Class  Marks      Country
# 0    Atif     MCA    100       German
# 1  Faisal  B.tech    140     Pakistan
# 2    Khan     BCA    120        China
# 3   Hatim  M.tech    300        Japan
# 4    Amir  C.Sci.    190        Dubai
# 5       B      11     12       Kuwait
# 6       C      12     45       German
# 7       D       9     67       German
# 8       E       8     54  Saudia Arab

# %%
df.drop(columns=['Marks'], inplace=True)
df
# Out:
#      Name   Class      Country
# 0    Atif     MCA       German
# 1  Faisal  B.tech     Pakistan
# 2    Khan     BCA        China
# 3   Hatim  M.tech        Japan
# 4    Amir  C.Sci.        Dubai
# 5       B      11       Kuwait
# 6       C      12       German
# 7       D       9       German
# 8       E       8  Saudia Arab

# %%
df.drop(index=7)
# Out:
#      Name   Class      Country
# 0    Atif     MCA       German
# 1  Faisal  B.tech     Pakistan
# 2    Khan     BCA        China
# 3   Hatim  M.tech        Japan
# 4    Amir  C.Sci.        Dubai
# 5       B      11       Kuwait
# 6       C      12       German
# 8       E       8  Saudia Arab

# %%
df.drop(index=7, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-ea210b2e2749> in <module>()
# ----> 1 df.drop(index=7, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df
# Out:
#      Name   Class      Country
# 0    Atif     MCA       German
# 1  Faisal  B.tech     Pakistan
# 2    Khan     BCA        China
# 3   Hatim  M.tech        Japan
# 4    Amir  C.Sci.        Dubai
# 5       B      11       Kuwait
# 6       C      12       German
# 8       E       8  Saudia Arab

# %%
df.sort_values(by='Name')
# Out:
#      Name   Class      Country
# 4    Amir  C.Sci.        Dubai
# 0    Atif     MCA       German
# 5       B      11       Kuwait
# 6       C      12       German
# 8       E       8  Saudia Arab
# 1  Faisal  B.tech     Pakistan
# 3   Hatim  M.tech        Japan
# 2    Khan     BCA        China

# %%
df.sort_values(by=['Name','Country'], ascending=False)
# Out:
#      Name   Class      Country
# 2    Khan     BCA        China
# 3   Hatim  M.tech        Japan
# 1  Faisal  B.tech     Pakistan
# 8       E       8  Saudia Arab
# 6       C      12       German
# 5       B      11       Kuwait
# 0    Atif     MCA       German
# 4    Amir  C.Sci.        Dubai

# %%
df.sort_values(by=['Name','Country'], ascending=True)
# Out:
#      Name   Class      Country
# 4    Amir  C.Sci.        Dubai
# 0    Atif     MCA       German
# 5       B      11       Kuwait
# 6       C      12       German
# 8       E       8  Saudia Arab
# 1  Faisal  B.tech     Pakistan
# 3   Hatim  M.tech        Japan
# 2    Khan     BCA        China

# %% [markdown]
# ###Again I am adding **Marks Columns**

# %%
marks= [56,72,80,76,60,82,32,79]
df['Marks']=marks
df
# Out:
#      Name   Class      Country  Marks
# 0    Atif     MCA       German     56
# 1  Faisal  B.tech     Pakistan     72
# 2    Khan     BCA        China     80
# 3   Hatim  M.tech        Japan     76
# 4    Amir  C.Sci.        Dubai     60
# 5       B      11       Kuwait     82
# 6       C      12       German     32
# 8       E       8  Saudia Arab     79

# %% [markdown]
# ##**Statistics in Pandas**

# %%
df['Marks'].median()
# Out:
# 74.0

# %%
df['Marks'].mode()
# Out:
# 0    32
# 1    56
# 2    60
# 3    72
# 4    76
# 5    79
# 6    80
# 7    82
# dtype: int64

# %%
df['Marks'].mean()
# Out:
# 67.125

# %%
df['Marks'].std()
# Out:
# 17.066571335299226

# %%
df['Marks']. describe()
# Out:
# count     8.000000
# mean     67.125000
# std      17.066571
# min      32.000000
# 25%      59.000000
# 50%      74.000000
# 75%      79.250000
# max      82.000000
# Name: Marks, dtype: float64

# %%
df['Marks'].max()
# Out:
# 82

# %%
df['Marks'].min()
# Out:
# 32

# %%
df['Marks'].count()
# Out:
# 8

# %%
df['Marks'].value_counts()
# Out:
# 56    1
# 72    1
# 80    1
# 76    1
# 60    1
# 82    1
# 32    1
# 79    1
# Name: Marks, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# German         2
# Pakistan       1
# China          1
# Japan          1
# Dubai          1
# Kuwait         1
# Saudia Arab    1
# Name: Country, dtype: int64

# %%
df
# Out:
#      Name   Class      Country  Marks
# 0    Atif     MCA       German     56
# 1  Faisal  B.tech     Pakistan     72
# 2    Khan     BCA        China     80
# 3   Hatim  M.tech        Japan     76
# 4    Amir  C.Sci.        Dubai     60
# 5       B      11       Kuwait     82
# 6       C      12       German     32
# 8       E       8  Saudia Arab     79

# %% [markdown]
# ###Adding row with **null value**

# %%
df.append({'Name':'Ragib','Class':'BSC','Country':'German'},ignore_index=True)
# Out:
#      Name   Class      Country  Marks
# 0    Atif     MCA       German   56.0
# 1  Faisal  B.tech     Pakistan   72.0
# 2    Khan     BCA        China   80.0
# 3   Hatim  M.tech        Japan   76.0
# 4    Amir  C.Sci.        Dubai   60.0
# 5       B      11       Kuwait   82.0
# 6       C      12       German   32.0
# 7       E       8  Saudia Arab   79.0
# 8   Ragib     BSC       German    NaN

# %% [markdown]
# ###Removing **null value**

# %%
df.dropna()
# Out:
#      Name   Class      Country  Marks
# 0    Atif     MCA       German     56
# 1  Faisal  B.tech     Pakistan     72
# 2    Khan     BCA        China     80
# 3   Hatim  M.tech        Japan     76
# 4    Amir  C.Sci.        Dubai     60
# 5       B      11       Kuwait     82
# 6       C      12       German     32
# 8       E       8  Saudia Arab     79

# %% [markdown]
# ##**Creating file**

# %%
df.to_csv('Demo')

# %% [markdown]
# ###Going to read file

# %%
df=pd.read_csv('Demo')
df
# Out:
#    Unnamed: 0    Name   Class      Country  Marks
# 0           0    Atif     MCA       German     56
# 1           1  Faisal  B.tech     Pakistan     72
# 2           2    Khan     BCA        China     80
# 3           3   Hatim  M.tech        Japan     76
# 4           4    Amir  C.Sci.        Dubai     60
# 5           5       B      11       Kuwait     82
# 6           6       C      12       German     32
# 7           8       E       8  Saudia Arab     79

# %% [markdown]
# **For more information visit website :** pandad.pydata.org

# %%
df
# Out:
#    Unnamed: 0    Name   Class      Country  Marks
# 0           0    Atif     MCA       German     56
# 1           1  Faisal  B.tech     Pakistan     72
# 2           2    Khan     BCA        China     80
# 3           3   Hatim  M.tech        Japan     76
# 4           4    Amir  C.Sci.        Dubai     60
# 5           5       B      11       Kuwait     82
# 6           6       C      12       German     32
# 7           8       E       8  Saudia Arab     79

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8 non-null      int64
#  1   Name        8 non-null      object
#  2   Class       8 non-null      object
#  3   Country     8 non-null      object
#  4   Marks       8 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 448.0+ bytes

# %% [markdown]
# ###Removing **Duplicates**

# %%
df.drop_duplicates()
# Out:
#    Unnamed: 0    Name   Class      Country  Marks
# 0           0    Atif     MCA       German     56
# 1           1  Faisal  B.tech     Pakistan     72
# 2           2    Khan     BCA        China     80
# 3           3   Hatim  M.tech        Japan     76
# 4           4    Amir  C.Sci.        Dubai     60
# 5           5       B      11       Kuwait     82
# 6           6       C      12       German     32
# 7           8       E       8  Saudia Arab     79

# %%
df.drop_duplicates(subset=['Country'])
# Out:
#    Unnamed: 0    Name   Class      Country  Marks
# 0           0    Atif     MCA       German     56
# 1           1  Faisal  B.tech     Pakistan     72
# 2           2    Khan     BCA        China     80
# 3           3   Hatim  M.tech        Japan     76
# 4           4    Amir  C.Sci.        Dubai     60
# 5           5       B      11       Kuwait     82
# 7           8       E       8  Saudia Arab     79
